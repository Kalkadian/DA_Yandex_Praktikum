# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузим-данные-и-подготовим-их-к-анализу" data-toc-modified-id="Загрузим-данные-и-подготовим-их-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузим данные и подготовим их к анализу</a></span><ul class="toc-item"><li><span><a href="#импортирую-библиотеки" data-toc-modified-id="импортирую-библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>импортирую библиотеки</a></span></li><li><span><a href="#загрузим-и-изучим-данные" data-toc-modified-id="загрузим-и-изучим-данные-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>загрузим и изучим данные</a></span><ul class="toc-item"><li><span><a href="#Изменение-данных" data-toc-modified-id="Изменение-данных-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Изменение данных</a></span></li></ul></li><li><span><a href="#Посмотрим-на-распределение-количественных-данных-через-гистограммы" data-toc-modified-id="Посмотрим-на-распределение-количественных-данных-через-гистограммы-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Посмотрим на распределение количественных данных через гистограммы</a></span></li><li><span><a href="#Проверим-пропуску" data-toc-modified-id="Проверим-пропуску-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверим пропуску</a></span></li><li><span><a href="#Проверим-на-явные-дубликаты" data-toc-modified-id="Проверим-на-явные-дубликаты-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверим на явные дубликаты</a></span></li><li><span><a href="#Проверим-на-неявные-дубликаты" data-toc-modified-id="Проверим-на-неявные-дубликаты-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Проверим на неявные дубликаты</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Задаем-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Задаем-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задаем функции для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span><ul class="toc-item"><li><span><a href="#Профили-рользователей" data-toc-modified-id="Профили-рользователей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Профили рользователей</a></span></li><li><span><a href="#Retention-Rate,-или-коэффициент-удержания" data-toc-modified-id="Retention-Rate,-или-коэффициент-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Retention Rate, или коэффициент удержания</a></span></li><li><span><a href="#Функция-для-расчета-конверсии" data-toc-modified-id="Функция-для-расчета-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчета конверсии</a></span></li><li><span><a href="#Функиция-для-расчета-LTV-и-ROI" data-toc-modified-id="Функиция-для-расчета-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функиция для расчета LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания" data-toc-modified-id="Функция-для-сглаживания-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания</a></span></li><li><span><a href="#Функция-для-расчета-графика-удержания" data-toc-modified-id="Функция-для-расчета-графика-удержания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для расчета графика удержания</a></span></li><li><span><a href="#Функиция-для-расчета-графиков-конверсии" data-toc-modified-id="Функиция-для-расчета-графиков-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функиция для расчета графиков конверсии</a></span></li><li><span><a href="#Функция-для-расчета-графиков-LTV-и-ROI" data-toc-modified-id="Функция-для-расчета-графиков-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для расчета графиков LTV и ROI</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Создаем-профили" data-toc-modified-id="Создаем-профили-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создаем профили</a></span></li><li><span><a href="#Проверим--максимальную-и-минимальную-дату-привлечения" data-toc-modified-id="Проверим--максимальную-и-минимальную-дату-привлечения-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Проверим  максимальную и минимальную дату привлечения</a></span></li><li><span><a href="#Создадим-функцию-для-построения-круговых-диаграмм." data-toc-modified-id="Создадим-функцию-для-построения-круговых-диаграмм.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Создадим функцию для построения круговых диаграмм.</a></span></li><li><span><a href="#Проверим-на-какую-страну-приходится-больше-всего-пользователей" data-toc-modified-id="Проверим-на-какую-страну-приходится-больше-всего-пользователей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Проверим на какую страну приходится больше всего пользователей</a></span><ul class="toc-item"><li><span><a href="#Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны." data-toc-modified-id="Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны.-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.</a></span></li></ul></li><li><span><a href="#Какие-устройства-предпочитают--пользователи" data-toc-modified-id="Какие-устройства-предпочитают--пользователи-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Какие устройства предпочитают  пользователи</a></span><ul class="toc-item"><li><span><a href="#Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-на-каждом-устройстве." data-toc-modified-id="Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-на-каждом-устройстве.-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Построим таблицу, отражающую количество пользователей и долю платящих на каждом устройстве.</a></span></li></ul></li><li><span><a href="#Через-какие-рекламные-каналы--приходят-пользователи" data-toc-modified-id="Через-какие-рекламные-каналы--приходят-пользователи-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Через какие рекламные каналы  приходят пользователи</a></span><ul class="toc-item"><li><span><a href="#Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-пришедших-через-тот-или-иной-канал-привлечения." data-toc-modified-id="Построим-таблицу,-отражающую-количество-пользователей-и-долю-платящих-пришедших-через-тот-или-иной-канал-привлечения.-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Построим таблицу, отражающую количество пользователей и долю платящих пришедших через тот или иной канал привлечения.</a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Маркетинговое-исследование" data-toc-modified-id="Маркетинговое-исследование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинговое исследование</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-общие-затраты" data-toc-modified-id="Посчитаем-общие-затраты-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посчитаем общие затраты</a></span></li><li><span><a href="#Построим-визуализацию-динамики-изменения-расходов-во-времени-(по-неделям-и-месяцам)-по-каждому-источнику." data-toc-modified-id="Построим-визуализацию-динамики-изменения-расходов-во-времени-(по-неделям-и-месяцам)-по-каждому-источнику.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Построим визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику.</a></span></li><li><span><a href="#Узнаем,-сколько-в-среднем-стоило-привлечение-одного-пользователя--из-каждого-источника" data-toc-modified-id="Узнаем,-сколько-в-среднем-стоило-привлечение-одного-пользователя--из-каждого-источника-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Узнаем, сколько в среднем стоило привлечение одного пользователя  из каждого источника</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Оценим-окупаемость-рекламы-и-выявим-возможные-сложности" data-toc-modified-id="Оценим-окупаемость-рекламы-и-выявим-возможные-сложности-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценим окупаемость рекламы и выявим возможные сложности</a></span><ul class="toc-item"><li><span><a href="#добавим-горизонт-анализа" data-toc-modified-id="добавим-горизонт-анализа-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>добавим горизонт анализа</a></span></li><li><span><a href="#Исключим-внебюджетный-канал-привлечения" data-toc-modified-id="Исключим-внебюджетный-канал-привлечения-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Исключим внебюджетный канал привлечения</a></span></li><li><span><a href="#Посторим-графики" data-toc-modified-id="Посторим-графики-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Посторим графики</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-окупаемость-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI" data-toc-modified-id="Проанализируем-окупаемость-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графики-динамики-LTV,-CAC-и-ROI-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI</a></span></li><li><span><a href="#Проанализируйте-окупаемость-рекламы-с-разбивкой-по-устройствам." data-toc-modified-id="Проанализируйте-окупаемость-рекламы-с-разбивкой-по-устройствам.-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Проанализируйте окупаемость рекламы с разбивкой по устройствам.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-каналам-привлечения" data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-каналам-привлечения-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по каналам привлечения</a></span></li><li><span><a href="#Проверим-конверсию-пользователей-и-динамику-её-изменения-по-каналам-привлечения" data-toc-modified-id="Проверим-конверсию-пользователей-и-динамику-её-изменения-по-каналам-привлечения-5.3.5"><span class="toc-item-num">5.3.5&nbsp;&nbsp;</span>Проверим конверсию пользователей и динамику её изменения по каналам привлечения</a></span></li><li><span><a href="#Проверим--удержание-пользователей-по-каналам-привлечения" data-toc-modified-id="Проверим--удержание-пользователей-по-каналам-привлечения-5.3.6"><span class="toc-item-num">5.3.6&nbsp;&nbsp;</span>Проверим  удержание пользователей по каналам привлечения</a></span></li><li><span><a href="#Проверим-конверсию-пользователей-и-динамику-её-изменения-по-странам" data-toc-modified-id="Проверим-конверсию-пользователей-и-динамику-её-изменения-по-странам-5.3.7"><span class="toc-item-num">5.3.7&nbsp;&nbsp;</span>Проверим конверсию пользователей и динамику её изменения по странам</a></span></li><li><span><a href="#Проверим--удержание-пользователей-по-странам" data-toc-modified-id="Проверим--удержание-пользователей-по-странам-5.3.8"><span class="toc-item-num">5.3.8&nbsp;&nbsp;</span>Проверим  удержание пользователей по странам</a></span></li><li><span><a href="#Проверим-конверсию-пользователей-и-динамику-её-изменения-по--устройствам" data-toc-modified-id="Проверим-конверсию-пользователей-и-динамику-её-изменения-по--устройствам-5.3.9"><span class="toc-item-num">5.3.9&nbsp;&nbsp;</span>Проверим конверсию пользователей и динамику её изменения по  устройствам</a></span></li><li><span><a href="#Проверим--удержание-пользователей-по-устройствам" data-toc-modified-id="Проверим--удержание-пользователей-по-устройствам-5.3.10"><span class="toc-item-num">5.3.10&nbsp;&nbsp;</span>Проверим  удержание пользователей по устройствам</a></span></li><li><span><a href="#Дополнительно-посмотрим-на-каналы-привлечения-из-США" data-toc-modified-id="Дополнительно-посмотрим-на-каналы-привлечения-из-США-5.3.11"><span class="toc-item-num">5.3.11&nbsp;&nbsp;</span>Дополнительно посмотрим на каналы привлечения из США</a></span></li><li><span><a href="#Дополнительно-посмотрим-на-устройтсва--из-США" data-toc-modified-id="Дополнительно-посмотрим-на-устройтсва--из-США-5.3.12"><span class="toc-item-num">5.3.12&nbsp;&nbsp;</span>Дополнительно посмотрим на устройтсва  из США</a></span></li><li><span><a href="#Дополнительно-посмотрим-на-каналы-привлечения-из-Европы" data-toc-modified-id="Дополнительно-посмотрим-на-каналы-привлечения-из-Европы-5.3.13"><span class="toc-item-num">5.3.13&nbsp;&nbsp;</span>Дополнительно посмотрим на каналы привлечения из Европы</a></span></li><li><span><a href="#Дополнительно-посмотрим-на-устройтсва-из-Европы" data-toc-modified-id="Дополнительно-посмотрим-на-устройтсва-из-Европы-5.3.14"><span class="toc-item-num">5.3.14&nbsp;&nbsp;</span>Дополнительно посмотрим на устройтсва из Европы</a></span></li></ul></li></ul></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общие выводы</a></span></li></ul></div>

# %% [markdown]
# # Исследование
#
# Развлекательное приложение Procrastinate Pro+, несмотря на огромные вложения в рекламу, последние несколько месяцев терпит убытки. Предоставлены логи с данными пользователей за определенный период, необходио разобраться в причинах убытков с учетом крупных затрат на рекламу и помочь компании выйти в плюс.
#
#
# ЦЕЛЬ ИССЛЕДОВАНИЯ:Необходимо изучить, поведение пользователей, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.

# %% [markdown]
# ПЛАН РАБОТ:
#
# - выгрузить данные, провести первичный предпросмотр
# - очистить данные от пропусков и дубликатов
# - изменить тип данных при необходимости
# - задать функции для определения:
#    - профилей
#    - конверсии
#    - удержания
#    - построени графиков
# - провести исследовательский по:
#    - проверим на какую страну приходится больше всего пользователей
#    - какие устройства предпочитают пользователи
#    - через какие рекламные каналы приходят пользователи
# - провести маркетинговое исследование:
#    - определить общие затраты на рекламы
#    - определить бюджеты на каналы привлечения
#    - определить среднюю стоимость привлечения пользователя
# - посторить графики по заданным функициям и оценить окупаемоть рекламы и выявить проблемы
# - сделать выводы и дать рекомендации заказчику

# %% [markdown]
# ОПИСАНИЕ ДАННЫХ:
#
# Данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года
#
# Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#
#  - User Id — уникальный идентификатор пользователя
#  - Device — категория устройства пользователя
#  - Session start — дата и время начала сессии
#  - Session End — дата и время окончания сессии
#  - Channel — идентификатор рекламного источника, из которого пришел пользователь
#  - Region - страна пользователя
#
# Таблица orders_log_short (информация о заказах):
#
# - User Id — уникальный id пользователя, который сделал заказ
# - Event Dt — дата и время покупки
# - Revenue — выручка
#
# Таблица costs_short (информация о затратах на маркетинг):
#
# - Channel — идентификатор рекламного источника
# - Dt — дата
# - Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# ### Загрузим данные и подготовим их к анализу

# %% [markdown]
# #### импортирую библиотеки

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %% [markdown]
# #### загрузим и изучим данные

# %%
try:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
    orders = pd.read_csv('/datasets/orders_info_short.csv')
    costs = pd.read_csv('/datasets/costs_info_short.csv')
    events = None
except Exception as e:
    print("An error occurred:", str(e))
    visits = pd.DataFrame()
    orders = pd.DataFrame()
    costs = pd.DataFrame()
    events = pd.DataFrame()

# %%
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Комментарий:
#     -  По итогу изучения наблюдаю, что не совпадает значение формата по столбцам с датой и временем. Сделаем замену с objecrt на datetime. Также необходимо поменять верхний регистр и пробелы заменить на '_'.

# %% [markdown]
# ##### Изменение данных

# %%
visits.columns = visits.columns.str.replace(' ', '_')
visits.columns = visits.columns.str.lower()

visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

orders.columns = orders.columns.str.replace(' ', '_')
orders.columns = orders.columns.str.lower()

orders['event_dt'] = pd.to_datetime(orders['event_dt'])

costs.columns = costs.columns.str.lower()
### замена пробелов не требуется
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# Замена произведена

# %% [markdown]
# #### Посмотрим на распределение количественных данных через гистограммы

# %%
visits.hist(figsize=(15,7),bins=100);

# %% [markdown]
# Комментарий:
#  - кол-во пользователей распределено равномерно
#  - кол-во сессий имеет пик на дате 2019-10

# %%
orders.hist(figsize=(15,7),bins=100);

# %% [markdown]
# комментарий:
#  - основая выручка распределена в районе 5. Также наблюдаются выбросы до в району 10,20,50

# %%
costs.hist(figsize=(15,7),bins=100);

# %% [markdown]
# Комментарий:
#  - основные расходы распределены до 50. Далее расходы распределены до 700.

# %% [markdown]
# #### Проверим пропуску

# %%
visits.isna().sum()
# Out:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64

# %%
orders.isna().sum()
# Out:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %%
costs.isna().sum()
# Out:
# dt         0
# channel    0
# costs      0
# dtype: int64

# %% [markdown]
# Комментарий:
#  - пропусков не обнаружено

# %% [markdown]
# #### Проверим на явные дубликаты

# %%
visits.duplicated().sum()
# Out:
# 0

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Комментрий:
#  - Явных дубликатов не обнаружено

# %% [markdown]
# #### Проверим на неявные дубликаты

# %%
visits[visits.duplicated(['user_id','region','device','channel','session_start','session_end'])]
# Out:
# Empty DataFrame
# Columns: [user_id, region, device, channel, session_start, session_end]
# Index: []

# %%
orders[orders.duplicated(['user_id','event_dt','revenue'])]
# Out:
# Empty DataFrame
# Columns: [user_id, event_dt, revenue]
# Index: []

# %%
costs[costs.duplicated(['dt','channel','costs'])]
# Out:
# Empty DataFrame
# Columns: [dt, channel, costs]
# Index: []

# %% [markdown]
# комментарий:
# - явных дубликатов не обнаружено

# %% [markdown]
# #### Вывод:
#  - Данные находятся в хорошем состоянии.Дубликатов или пропусков не обнаруженно. Для удобства работы с базами были внесены изменения по формату данных, перевели столбцы с датами в формат date. Также названия столбцов были приведены к формату snake_case и изменен регистр.

# %% [markdown]
# ### Задаем функции для расчёта и анализа LTV, ROI, удержания и конверсии.

# %% [markdown]
# #### Профили рользователей

# %%
def get_profiles(sessions, orders, costs):
    # находим параметры первых посещений
    profiles = (sessions.sort_values(by=['user_id', 'session_start'])
                .groupby('user_id')
                .agg(
                    {
                        'session_start' : 'first',
                        'channel' : 'first',
                        'device' : 'first',
                        'region' : 'first'
                    }
                )
                .rename(columns={'session_start' : 'first_ts'})
                .reset_index()
               )
    
    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    
    # добавляем признак пользователей, совершивших покупку
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())
    
    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
    
    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = costs.merge(new_users, on=['dt', 'channel'], how='left')
    
    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    
    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    
    return profiles

# %% [markdown]
# #### Retention Rate, или коэффициент удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):
    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions
    
    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days=horizon_days - 1)
    result_raw  = profiles.query('dt <= @last_suitable_acquisition_date')
    
    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days
    
    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Функция для расчета конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### Функиция для расчета LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# #### Функция для сглаживания

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# #### Функция для расчета графика удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Функиция для расчета графиков конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Функция для расчета графиков LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Все необходимые функции добавлены

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Создаем профили

# %%
profiles = get_profiles(visits,orders,costs)
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# Комментарий:
#  - Профили созданы успешно

# %% [markdown]
# #### Проверим  максимальную и минимальную дату привлечения

# %%
max_ts = profiles['first_ts'].max()
f'Максимальная дата привлечения: {max_ts}'
# Out:
# 'Максимальная дата привлечения: 2019-10-27 23:59:04'

# %%
min_ts = profiles['first_ts'].min()
f'Минимальная дата привлечения: {min_ts}'
# Out:
# 'Минимальная дата привлечения: 2019-05-01 00:00:41'

# %% [markdown]
# Комментарий:
#  - дата начала привлечения 05 января по 27 октября 2019 года соответственно. Информация покрывает 5 месяцев

# %% [markdown]
# #### Создадим функцию для построения круговых диаграмм.

# %%
def pie(dataframe, label_column, value_column):
    
    labels = dataframe[label_column]
    sizes = dataframe[value_column]

    
    fig,ax = plt.subplots()
    ax.pie(sizes, labels=labels, autopct='%1.1f%%')
    fig.set_size_inches(7, 7)
    plt.show()

# %% [markdown]
# #### Проверим на какую страну приходится больше всего пользователей

# %%
region_users = profiles.groupby('region').agg({'user_id': 'nunique'}).reset_index()

pie(region_users,'region','user_id')

region_users.sort_values('user_id', ascending=False).reset_index(drop=True)
# Out:
#           region  user_id
# 0  United States   100002
# 1             UK    17575
# 2         France    17450
# 3        Germany    14981

# %% [markdown]
# Комментарий:
#  - Подавляющее большинство используют приложение в США. 66,7% или 100002 от общего числа пользователей.

# %% [markdown]
# ##### Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
region_payer = profiles[profiles['payer'] == True].groupby('region').agg({'payer': 'count'}).reset_index()
region_payer['ratio'] = round((region_payer['payer'] / region_users['user_id']*100),2)

pie(region_payer,'region','payer')

region_payer.sort_values('ratio', ascending=False).reset_index(drop=True)
# Out:
#           region  payer  ratio
# 0  United States   6902   6.90
# 1        Germany    616   4.11
# 2             UK    700   3.98
# 3         France    663   3.80

# %% [markdown]
# Комментарий:
#  - Также большинство платящих из США. 77.7% от общего числа плательщиков.
#  - Доля платящих из США также выше остальных 6.9%

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Правильно, причем даже если суммарно сложить всех пользователей (в том числе и платящих) прочих стран мы едва получим половину от всех пользователей Штатов, при этом и доля покупателей у Америки самая высокая с отрывом</div>

# %% [markdown]
# ####  Какие устройства предпочитают  пользователи

# %%
device_users = profiles.groupby('device').agg({'user_id': 'nunique'}).reset_index()

pie(device_users,'device','user_id')

device_users.sort_values('user_id', ascending=False).reset_index(drop=True)
# Out:
#     device  user_id
# 0   iPhone    54479
# 1  Android    35032
# 2       PC    30455
# 3      Mac    30042

# %% [markdown]
# Комментарий:
#      - Большинство пользуеются телефонами iphone - 36.3% или 54479 от общего кол-ва.
#      - На остальные платформы распределение близко друг другу в районе от 20 до 24%

# %% [markdown]
# ##### Построим таблицу, отражающую количество пользователей и долю платящих на каждом устройстве.

# %%
device_payer = profiles[profiles['payer'] == True].groupby('device').agg({'payer': 'count'}).reset_index()
device_payer['ratio'] = round((device_payer['payer'] / device_users['user_id']*100),2)

pie(device_payer,'device','payer')

device_payer.sort_values('ratio', ascending=False).reset_index(drop=True)
# Out:
#     device  payer  ratio
# 0      Mac   1912   6.36
# 1   iPhone   3382   6.21
# 2  Android   2050   5.85
# 3       PC   1537   5.05

# %% [markdown]
# Комментарий:
#  - Большинство платящих пользователей используют iphone - 38.1% от общего числа.Но отношение платных пользователей к кол-ву общих пользователей на платформе имеют пользователи Mac 6.36 против 6.21 на iphone

# %% [markdown]
# #### Через какие рекламные каналы  приходят пользователи

# %%
channel_users = profiles.groupby('channel').agg({'user_id': 'nunique'}).reset_index()

pie(channel_users,'channel','user_id')

channel_users.sort_values('user_id', ascending=False).reset_index(drop=True)
# Out:
#                channel  user_id
# 0              organic    56439
# 1             FaceBoom    29144
# 2               TipTop    19561
# 3   OppleCreativeMedia     8605
# 4              LeapBob     8553
# 5       WahooNetBanner     8553
# 6       RocketSuperAds     4448
# 7         MediaTornado     4364
# 8              YRabbit     4312
# 9           AdNonSense     3880
# 10      lambdaMediaAds     2149

# %% [markdown]
# Комментарий:
# - Большинство приходят через канал Organic - 56439 пользователей или 37,6% от общего кол-ва.

# %% [markdown]
# ##### Построим таблицу, отражающую количество пользователей и долю платящих пришедших через тот или иной канал привлечения.

# %%
channel_payer = profiles[profiles['payer'] == True].groupby('channel').agg({'payer': 'count'}).reset_index()
channel_payer['ratio'] = round((channel_payer['payer'] / channel_users['user_id']*100),2)

pie(channel_payer,'channel','payer')

channel_payer.sort_values('ratio', ascending=False).reset_index(drop=True)
# Out:
#                channel  payer  ratio
# 0             FaceBoom   3557  12.20
# 1           AdNonSense    440  11.34
# 2       lambdaMediaAds    225  10.47
# 3               TipTop   1878   9.60
# 4       RocketSuperAds    352   7.91
# 5       WahooNetBanner    453   5.30
# 6              YRabbit    165   3.83
# 7         MediaTornado    156   3.57
# 8              LeapBob    262   3.06
# 9   OppleCreativeMedia    233   2.71
# 10             organic   1160   2.06

# %% [markdown]
# Комментарий:
#  - Кол-во платящих пользователей приходит через канал FaceBoom 40.1% или 3557. Отношение платящих пользователей к общему кол-ву пользователей канала привлечения также выше всего у FaceBoom 12.2%

# %% [markdown]
# #### Вывод:
#
# - Пользователи привлекаются из четырех стран Франция,Германия,Англия,США. Подавляющее большинство используют приложение в США. 66,7% или 100002 от общего числа пользователей.
# - Большинство платящих из США. 77.7% от общего числа плательщиков. Доля платящих из США также выше остальных 6.9%
# - Также приложение используется на четерых платформах iphone, Mac,Andoroid,PC.
# - Большинство пользуеются телефонами iphone - 36.3% или 54479 от общего кол-ва. На остальные платформы распределение близко друг другу в районе от 20 до 24%
# - Приложение имеет 10 каналов привлеченияю.Большинство приходят через канал Organic - 56439 пользователей или 37,6% от общего кол-ва. Кол-во платящих пользователей приходит через канал FaceBoom 40.1% или 3557. Отношение платящих пользователей к общему кол-ву пользователей канала привлечения также выше всего у FaceBoom 12.2%

# %% [markdown]
# ### Маркетинговое исследование

# %% [markdown]
# #### Посчитаем общие затраты

# %%
costs_sum = costs['costs'].sum()

# %%
costs_channel = costs.groupby('channel').agg({'costs':'sum'}).sort_values(by='costs',ascending=False)
costs_channel['costs_ratio'] = round((costs_channel['costs'] / costs_sum)*100,2)
costs_channel
# Out:
#                        costs  costs_ratio
# channel
# TipTop              54751.30        51.90
# FaceBoom            32445.60        30.75
# WahooNetBanner       5151.00         4.88
# AdNonSense           3911.25         3.71
# OppleCreativeMedia   2151.25         2.04
# RocketSuperAds       1833.00         1.74
# LeapBob              1797.60         1.70
# lambdaMediaAds       1557.60         1.48
# MediaTornado          954.48         0.90
# YRabbit               944.22         0.90

# %% [markdown]
# Комментарий:
# - Общие затраты на рекламу составили 105 947.30 долларов
# - Сам затратный канал привлечения TipTop 54751,затем 32445 FaceBoom.Разница затрат между первыми двумя и остальными каналами привленчения имеет 10-ти кратный разрыв
# - Канал Organic отсутствует в подсчете. Видимо на канал затраты не производились, хотя кол-во общих привлеченных пользователей там самое большое

# %% [markdown]
# #### Построим визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику.

# %%
costs['dt'] = pd.to_datetime(costs['dt'], format='%Y-%m-%d')

# %%
costs['week'] = costs['dt'].dt.isocalendar().week
filtered_df_week = costs.query('channel != ["TipTop","FaceBoom"]')
grouped_week = costs.groupby(['channel', 'week']).agg({'costs': 'sum'}).reset_index()
grouped_week_filtered = filtered_df_week.groupby(['channel', 'week']).agg({'costs': 'sum'}).reset_index()

costs['month'] = costs['dt'].dt.month
filtered_df_month = costs.query('channel != ["TipTop","FaceBoom"]')
grouped_month = costs.groupby(['channel', 'month']).agg({'costs': 'sum'}).reset_index()
grouped_month_filtered = filtered_df_month.groupby(['channel', 'month']).agg({'costs': 'sum'}).reset_index()

# Построение первого графика по неделям
plt.subplot(2, 2, 1)
for channel in grouped_week['channel'].unique():
    costs = grouped_week[grouped_week['channel'] == channel]
    plt.plot(costs['week'], costs['costs'], label=channel)
plt.xlabel('Неделя')
plt.ylabel('Затраты')
plt.title('Динамика изменения расходов по неделям')
plt.gcf().set_size_inches(20, 9)
plt.grid() 
plt.legend()

# Построение второго графика по месяцам
plt.subplot(2, 2, 2)
for channel in grouped_month['channel'].unique():
    costs = grouped_month[grouped_month['channel'] == channel]
    plt.plot(costs['month'], costs['costs'], label=channel)
plt.xlabel('Месяц')
plt.ylabel('Затраты')
plt.title('Динамика изменения расходов по месяцам')
plt.gcf().set_size_inches(20, 9)
plt.grid() 
plt.legend()

# Построение третьего графика по неделям без TipTop и FaceBoom
plt.subplot(2, 2, 3)
for channel in grouped_week_filtered['channel'].unique():
    costs = grouped_week_filtered [grouped_week_filtered ['channel'] == channel]
    plt.plot(costs['week'], costs['costs'], label=channel)
plt.xlabel('Неделя')
plt.ylabel('Затраты')
plt.title('Динамика изменения расходов по неделям')
plt.gcf().set_size_inches(20, 9)
plt.grid() 
plt.legend()

# Построение третьего графика по неделям без TipTop и FaceBoom

plt.subplot(2, 2, 4)
for channel in grouped_month_filtered['channel'].unique():
    costs = grouped_month_filtered[grouped_month_filtered['channel'] == channel]
    plt.plot(costs['month'], costs['costs'], label=channel)
plt.xlabel('Месяц')
plt.ylabel('Затраты')
plt.title('Динамика изменения расходов по месяцам')
plt.gcf().set_size_inches(20, 9)
plt.grid() 
plt.legend()


# Отображение графиков
plt.tight_layout()

# %% [markdown]
# Комментарий:
#  - Динамика затрат указывает указывает, что вложения в каналы привлечения TipTop и FaceBoom шла по восходящей тендеции, с провалом на 27 неделе, до 40 недели или 9 месяца, даллее наблюжается резкий спад.
#  - Траты на остальные источники достаточно равномерны, лидирует по тратам WahooNetBanner

# %% [markdown]
# #### Узнаем, сколько в среднем стоило привлечение одного пользователя  из каждого источника

# %%
prof_costs = profiles.groupby('channel').agg({'acquisition_cost':'mean','payer':'sum'}).sort_values(by='acquisition_cost',ascending=False)
prof_costs['average_cost'] = costs_channel['costs']/prof_costs['payer'] 
prof_costs.sort_values(by='average_cost', ascending=False)
prof_costs
# Out:
#                     acquisition_cost  payer  average_cost
# channel
# TipTop                      2.799003   1878     29.154047
# FaceBoom                    1.113286   3557      9.121619
# AdNonSense                  1.008054    440      8.889205
# lambdaMediaAds              0.724802    225      6.922667
# WahooNetBanner              0.602245    453     11.370861
# RocketSuperAds              0.412095    352      5.207386
# OppleCreativeMedia          0.250000    233      9.232833
# YRabbit                     0.218975    165      5.722545
# MediaTornado                0.218717    156      6.118462
# LeapBob                     0.210172    262      6.861069
# organic                     0.000000   1160           NaN

# %% [markdown]
# Комментарий:
# - TipTop имеет самую высокую среднею стоимость привлечения платящего пользователя 2.79, но в абсолютном выражении привлекает меньше таких пользователей чем канал Faceboom, 3557 против 1878.Траты на привлечение платящего пользователя через канал Faceboom практически в три раза меньше чем у TipTop

# %% [markdown]
# #### Вывод:
# - Всего на привлечение пользователей за полгода было потрачено 105,5 тысяч долларов
# - Бюджет на рекламу распределен между двумя основными каналами TipTop и Faceboom
# - Бюджет на TipTop самый крупный 54751.30, но привлечение платящих пользователей меньше чем у второго по бюджету канала Faceboom
# - В дальнейшем исследовании рассмотрим, как тратились эти бюджеты
# - Organic в расчет брать не будем так как на него бюджет не выделялся

# %% [markdown]
# ### Оценим окупаемость рекламы и выявим возможные сложности

# %% [markdown]
# #### добавим горизонт анализа

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %% [markdown]
# #### Исключим внебюджетный канал привлечения

# %%
prof = profiles.query('channel != "organic"')

# %% [markdown]
# #### Посторим графики

# %% [markdown]
# ##### Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(prof, orders, observation_date, horizon_days)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# комментарий:
# - LTV постепенно растет
# - Динамика LTV колеблится, но находится стабильно в одном диапазоне
# - САС растет на всем графике,с периодическим спадами.С учетом постоянного роста графика можно делать вывод, что рекламные кампании проводятся регулярно
# - ROI находится на уровне 80%, что говорит о том,что кампании не окупаются
# - Стоит отметить, что ROI показывал хорошую динамику но ближе к 4 динамика начинает земедляться

# %% [markdown]
# ##### Проанализируйте окупаемость рекламы с разбивкой по устройствам.

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    prof, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# комментарий:
#
# - Реклама не окупается везде, кроме PC
# - LTV стабилен везде
# - хуже всего окупаются владельцы Mac и iPhone
#
# дополнительно
# -Динамика ROI досточно волатильная для PC.Есть резкий провал в конце июля, а затем резкий рост в августе обратно выше окупаимости и затем планомерное снижение к концу октября. Даная динамика никак не коррелирует с динамикой СAC по PC.затраты не повышались и не снижались.Хотя общий провал по динамику ROI в конце июля характерен для всех девайсов. У андройда и PC все же после провала пошло восстановление в августе, а вот Mac и iphone таких результатов не показывют несмотря, что бюджет на привлечение на этих платформах растет.Стоит отметить что динамика ROI по андройду и PC стабилизировалась в сентября, в этот же период был увеличен CAC, что видимо помогло удержать ROI.

# %% [markdown]
# ##### Проанализируем окупаемость рекламы с разбивкой по странам

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    prof, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# комментарий:
# - во всех странах кроме США окупаемость превышает 100%, в а в США не окупается совсем.
# - CAC растет в США, а в Европе резко снижается в июне и дальше держится стабильно низко
# - ROI на 14 день опять же хуже всего в США, хотя в самом начале периода,примерно пол месяца в мае, находится выше линии окупаемости

# %% [markdown]
# ##### Проанализируем окупаемость рекламы с разбивкой по каналам привлечения

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    prof, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# комментарий:
# - во всех каналах, кроме TipTop, FaceBoom и AdNonSense реклама окупается
# - CAC растет в TipTop, а в остальных держится стабильно низко и даже немного падает
#
# дополнение:
# Отметим, что по показателю LTV TipTop имеет один из лучших показателей, но несмотря на это имеет низкий ROI. все же это связанно с высокими затратами. Возможно стоит сбалансировать бюджет для этого канала. Также канал lambaMediaAds имеет лучший LTV,в лидерах по ROI и имеет относительно низкие затраты. Возможно один из вариантов перераспределить часть бюджета от TipTop на этот канал, чтобы сбалансировать показатели.

# %% [markdown]
# ##### Проверим конверсию пользователей и динамику её изменения по каналам привлечения

# %%
dimensions = ['channel']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# комментарий:
# #- пользователи из всех сетей конвертируются достаточно хорошо, причем постоянно.#|
#
# По показателем видно,что хорошо в коверсии себя показывают Faceboom и TipTop, несмотря что по ROI не окупаются показыват здесь хорошие результаты. Также еще один явный лидер LambdaMedianAds. Остальные каналы показывают относительно низкую конверсию,что совпадает с их низким ROI и низкими затратами на этот канал. Перспективный канал исходя из предыдущих показателей LambdaMedianAds.

# %% [markdown]
# ##### Проверим  удержание пользователей по каналам привлечения

# %%
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# комментарий:
#
# - при достаточно высокой конверсии, удержание пользователей из FaceBoom и AdNonSense гораздо ниже, чем пользователей из других источников.
# - удержание пользователей TipTop довольно высокое и конверсия выше среднего. Видимо, это просто очень дорогой канал для рекламы.

# %% [markdown]
# ##### Проверим конверсию пользователей и динамику её изменения по странам

# %%
dimensions = ['region']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# комментарий:
#
# - конверсия по странам достаточно стабильная, но самая высока в США

# %% [markdown]
# ##### Проверим  удержание пользователей по странам

# %%
dimensions = ['region']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# комментарий:
# - Несмотря на высокую коверсию в США, ситуация с удержанием платящих клиентов в США показывает худший результат

# %% [markdown]
# ##### Проверим конверсию пользователей и динамику её изменения по  устройствам

# %%
dimensions = ['device']

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# комментарий:
# -  Несмотря на то, что окупаемость рекламы для пользователей PC выше всего, конверсия среди них ниже всех

# %% [markdown]
# ##### Проверим  удержание пользователей по устройствам

# %%
dimensions = ['device']

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# комменатарий:
# - удержание платящих пользователей на 14-й день у PC хуже всех, но старт досточно сильный

# %% [markdown]
# ##### Дополнительно посмотрим на каналы привлечения из США

# %%
prof_USA = profiles.query("region == 'United States'")

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    prof_USA, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=7
)

# %% [markdown]
# комментарий:
#
# - В США лидер по LTV  является TipTop, он же самы затратный. ROI у него также в зоне вне окупаемости.
# - Хорошо себя показывает канал RocketSuperAds. Имеет низкие расходы,которые со временем еще и снижаются, хороший ROI, динамику ROI и LTV. Кандидат на переспределение бюджета от TipTop

# %% [markdown]
# ##### Дополнительно посмотрим на устройтсва  из США

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    prof_USA, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# комментарий:
#
# - Лучший по динамике LTV это android, остальные имеют практически идентичный показатель
# - Расходы на Mac и iphone растут с одинаковой динамикой,а вот PC и android имеют определенную волатильность особенно PC
# - ROI у всех отрицательный.Android ближе всех к окупаемости, хотя ему еще 10 п.п. до зоны окупаемости.
# - Динамика ROI у всех схожая,она имеет корреляцию в расходах. В июне резкаий рост расходов по всем платформам, в этот же момент все провалились ниже зоны окупаемости. С временным возвратом выше зоны окупаемости в момент замедления расходов в июне

# %% [markdown]
# ##### Дополнительно посмотрим на каналы привлечения из Европы

# %%
prof_EU = prof.query("region != 'United States'")

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    prof_EU, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=7
)

# %% [markdown]
# комментарий:
#
#  - В Европе ситуация по LTV показывает лидера lambdaMediaAds она же лучшая по ROI. Также имеет второй по размеру бюджет на привлечение, что себя оправдывает.
#  - AdNonSense имеет самый большой бюджет на привлечение, но показывает относительно средний результат по LTV и совсем не окупается.Для балансировки можно распределить часть бюджета на lambdaMediaAds.
#  - Стоить отметить что бюджеты на привлечение распределены равномерно без резкого роста или спада в отличие от США

# %% [markdown]
# ##### Дополнительно посмотрим на устройтсва из Европы

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    prof_EU, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=7
)

# %% [markdown]
# комментарий:
#
# - Лидер по ROI и LTV здесь PC. Остальные платформы имею одинаковую динамику. Стоит отметить, что все назодятся выше зоны окупаемсоти
# - Расходы на рекламы имееют стабильную динамику, за исключением июня, когда произошло резкое снижение по всем платформам. На динамику ROI это повлияло положительно для Mac и iphone, они вышли в положительную зону

# %% [markdown]
# ### Общие выводы
#
# проанализировав активность пользователей и эффективность трат на рекламу за полгода, можно сказать, что аудитория приложения в США в разы выше, чем в странах Европы вместе взятых. Устройства, с которых пользователи делают покупки в среднем больше распространены устройства Apple.
# Каналы, которые не окупаются - TipTop, FaceBoom и AdNonSense.
#
# - На площадку TipTop была потрачена почти половина рекламного бюджета приложения, окупаемость очень низкая. Однако имеет хорошую конверсию и удержание пользователей.
# - Второй не окупающийся канал FaceBoom,также плохо с окупаемостью и худший показатель по удержнаию, но конверсия лучше всех.
# - AdNonSense имеет также хорошую конверсиб и удержание.
# Несмотря на очевидный провал по ROI, данные каналы имеют хорошие показатели по конверсии и удержанию. Каналы дорогие, возможно всеже стоит сбалансировать бюджеты и рассмотреть перераспределение в lambdaMediaAds и RocketSuperAds, что повысить эффективность по ROI.
#
# В разрезе стран стоит обратить внимание, что в США хорошая динамика у пользователей android. Хороший LTV и относительно осталных девайсов близкий к окупаемости ROI. Стоит несколько повысить бюджет на привлечение. Сейчас он опустился ниже остальных.
#
# В Европе самая популярная платформа, это PC. Бюджеты на привлечение в Европе досточно низкие и не сильно отличаются по отношению друг к другу.Глобальных изменений здесь возможно делать не стоит. Выглядит все сбалансировано. Возможно стоит повысить бюджет на MAC,он имеет не стабильную динамику по LTV и ROI, но положительные экстремумы имеют самые высокие пиковые значения среди всех.
